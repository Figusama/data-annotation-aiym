# %%
import whisper as wh

# %%
model = wh.load_model("small")

result = model.transcribe("/Volumes/T7/elarna/elarna_video_sorted_2020_2021/grade_01/subject_01/01_02_1_01_02.mp4")

print(result['text'])
# Out:
# 100%|███████████████████████████████████████| 461M/461M [01:46<00:00, 4.52MiB/s]
# /Users/almazbaktygali/Desktop/data-annotation-aiym/.data_env/lib/python3.13/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
with open("transcript_01_02_1_01_02.txt", "w") as f:
    f.write(result['text'])
