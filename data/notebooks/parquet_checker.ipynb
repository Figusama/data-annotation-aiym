# %%
import pandas as pd

pd.read_parquet("/Users/almazbaktygali/Desktop/data-annotation-aiym/data/test/parquets/elarna_hs_0to20467_0.parquet")
# Out:
#                                                     path hand_label  frame  \
# 0      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     19
# 1      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     20
# 2      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     30
# 3      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     31
# 4      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     32
# ...                                                  ...        ...    ...
# 20462  /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right  15675
# 20463  /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right  15676
# 20464  /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right  15677
# 20465  /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right  15678
# 20466  /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right  15679
#
# ...

# %%
pd.read_parquet("/Users/almazbaktygali/Desktop/data-annotation-aiym/data/test/parquets/elarna_hs_0to21042_0.parquet")
# Out:
#                                                     path hand_label  frame  \
# 0      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     36
# 1      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     37
# 2      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     38
# 3      /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left     38
# 4      /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left     39
# ...                                                  ...        ...    ...
# 21037  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left  14816
# 21038  /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right  14817
# 21039  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left  14817
# 21040  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left  14818
# 21041  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left  14819
#
# ...

# %%
pd.read_parquet("/Users/almazbaktygali/Desktop/data-annotation-aiym/data/test/parquets/elarna_hs_0to50000_0.parquet")
# Out:
#                                                     path hand_label  frame  \
# 0      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     36
# 1      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     37
# 2      /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right     38
# 3      /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left     38
# 4      /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left     39
# ...                                                  ...        ...    ...
# 49995  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left   5206
# 49996  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left   5207
# 49997  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left   5207
# 49998  /Volumes/T7/elarna/elarna_video_sorted_2020_20...       Left   5208
# 49999  /Volumes/T7/elarna/elarna_video_sorted_2020_20...      Right   5208
#
# ...
