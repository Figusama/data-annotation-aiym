# %%
python ./notebooks/videomae_encode.py \
        --records ./notebooks/surdobot_dataset_records.json \
        --video-root /run/media/gygy/T7/KRSL_OnlineSchool/KRSL_OnlineSchool_final_dataset/Surdobot_VideoBase \
        --out-dir /run/media/gygy/T7/KRSL_OnlineSchool/Videomae_features \
        --model MCG-NJU/videomae-base \
        --num-frames 16 \
        --batch-size 4 \
        --device cuda \
        --limit 5
# Out:
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).

# %%
import numpy as np

df = np.load('/run/media/gygy/T7/KRSL_OnlineSchool/surdobot_raw_hs_keypoints/resized_cropped_09_12_1_01_02-1-of-20.npy')

# %%
df.shape
